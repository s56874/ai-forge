# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/cleaned_house_price.csv")

# %%
df.head()
# Out:
#               area_type                  location    Area  bath  balcony  \
# 0  Super built-up  Area  Electronic City Phase II  1056.0   2.0      2.0
# 1  Super built-up  Area        Lingadheeranahalli  1521.0   3.0      3.0
# 2  Super built-up  Area                Whitefield  1170.0   2.0      2.0
# 3  Super built-up  Area        7th Phase JP Nagar  1000.0   2.0      2.0
# 4            Plot  Area                  Sarjapur  2250.0   3.0      3.0
#
#     price  bhk  area_per_bhk
# 0   39.07    2         528.0
# 1   95.00    3         507.0
# 2   38.00    2         585.0
# 3   38.00    2         500.0
# 4  148.00    3         750.0

# %%
df.tail()
# Out:
#                  area_type               location    Area  bath  balcony  \
# 6223  Super built-up  Area  Raja Rajeshwari Nagar  1187.0   2.0      2.0
# 6224        Built-up  Area      Bannerghatta Road  1527.0   3.0      3.0
# 6225  Super built-up  Area           Yeshwanthpur  1675.0   3.0      3.0
# 6226  Super built-up  Area      Green Glen Layout  1715.0   3.0      3.0
# 6227        Built-up  Area  Raja Rajeshwari Nagar  1141.0   2.0      2.0
#
#        price  bhk  area_per_bhk
# 6223   40.14    2    593.500000
# 6224  142.00    3    509.000000
# 6225   92.13    3    558.333333
# 6226  112.00    3    571.666667
# 6227   60.00    2    570.500000

# %%
df.shape
# Out:
# (6228, 8)

# %%
df.columns
# Out:
# Index(['area_type', 'location', 'Area', 'bath', 'balcony', 'price', 'bhk',
#        'area_per_bhk'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# area_type       0
# location        0
# Area            0
# bath            0
# balcony         0
# price           0
# bhk             0
# area_per_bhk    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns='area_type',inplace=True)

# %%
df.head()
# Out:
#                    location    Area  bath  balcony   price  bhk  area_per_bhk
# 0  Electronic City Phase II  1056.0   2.0      2.0   39.07    2         528.0
# 1        Lingadheeranahalli  1521.0   3.0      3.0   95.00    3         507.0
# 2                Whitefield  1170.0   2.0      2.0   38.00    2         585.0
# 3        7th Phase JP Nagar  1000.0   2.0      2.0   38.00    2         500.0
# 4                  Sarjapur  2250.0   3.0      3.0  148.00    3         750.0

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Area'],df['price'])
plt.title("Price vs  Area")
plt.xlabel("Area(Sqft)")
plt.ylabel("Price(in Lakh)")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
x = df[['Area']]
y = df['price']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=12)

# %%
print("Training Shape:",x_train.shape,y_train.shape)
print("Teesting Shape:",x_test.shape,y_test.shape)
# Out:
# Training Shape: (4982, 1) (4982,)
# Teesting Shape: (1246, 1) (1246,)

# %%
poly = PolynomialFeatures(degree=2)

X_train_poly = poly.fit_transform(x_train)
X_test_poly = poly.transform(x_test)

# %%
model = LinearRegression()
model.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
print("Training Accuraccy:",model.score(X_train_poly,y_train)*100)
# Out:
# Training Accuraccy: 58.09361591329507

# %%
print("Testing R² Score:", model.score(X_test_poly, y_test) * 100)
# Out:
# Testing R² Score: 60.745789321857856

# %%
y_pred = model.predict(X_test_poly)

# %%
print("R2 Score:",r2_score(y_test,y_pred)*100)
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
print("RMSE:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score: 60.745789321857856
# MAE: 15.130549430090726
# MSE: 436.4476945135082
# RMSE: 20.89133060658196

# %%
sns.scatterplot(x=x_test["Area"], y=y_test)

x_sorted = x_test.sort_values("Area")
x_sorted_poly = poly.transform(x_sorted)

plt.plot(
    x_sorted["Area"],
    model.predict(x_sorted_poly)
)

plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Polynomial Regression")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--",
    color='red'
)
plt.title("Multiple Linear Regression: Actual vs Predicted")
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.show()
