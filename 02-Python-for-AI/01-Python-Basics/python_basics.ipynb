# %%
# Python Basics Practice

## Microsoft Nirmaan AI Program

#Topics Covered:
#1.Print Statement
#2.Variables
#3.Data Types
#4.Input Output
#5.Operators
#6.Conditions
#6.Basic Programs

# 1.Print Statement
print("Hello World!")
print("Welcome to Python")
print("Microsoft AI Nirman Program")
print("="*30)
# 2.Variables
name = "Samarth"
age = 22
course = "Artificial Intelligence"

print(name)
print(age)
print(course)
print("="*30)

# 3.Data Types
name = "Samarth"
marks = 88.50
age = 22
is_student = True

print(type(name))
print(type(age))
print(type(marks))
print(type(is_student))
print("="*30)
#01.Integer
number = 20
#02.Float
marks = 88.50
#3.String
name = "Samarth"
#04.Boolean
is_student = True
print(number)
print(marks)
print(name)
print(is_student)
print("="*30)

# 4. Input and Output
name = input("Enter  your name:")
print("Hello",name)
print("="*30)

# Input with number
age = int(input("Enter your age:"))
print("Your age is",age)
print("="*30)

# 5.Operators
# In the python there are many typs of operator but following are the some types of operators in python.
#1-Arithmetic Operators (+,-,*,/,%,//,**)
#2-Assignment Operators (=,+=,-=,*=,/,=,%=,//=,**=)
#3-Comparison Operators (==,!=,>,<,>=,<=,is,is not)
#4-Logical Operators (and,or,not)
#5-Bitwise Operators (&,|,~,^,>>,<<)
#6-Membership Operators (in,not in)

a = 10
b = 20
print("Addition is:",a+b)
print("Substraction is:",a-b)
print("Multiplication is:",a*b)
print("Division is:",a/b)
print("Modulos is",a%b)
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a<=b)
print(a>=b)
print("="*30)


# 6.Condition
#1.If Condition
#2.If-else Condition
#3.If-elif-else Condition
#4.Nested if condition

#1.If condition
age = 18
if age >= 18:
  print("You are Eligible to Vote")

# 2.If-else Condition
if age >= 18:
  print("You are Eligible to Vote")
else:
  print("You ar not eligible to vote")
# 3.If-elif-else condition
marks = 80
if marks >= 90:
  print("Grade A")
elif marks >= 80:
  print("Grade B")
elif marks >= 70:
  print("Grade C")
elif marks >= 60:
  print("Grade D")
else:
  print("Grade F")

#4.Nested if condition
age = 20
has_id = True
if age >= 18:
  if has_id:
    print("Entery Allowed")
  else:
    print("Id Required")
else:
  print("Age is Not Allowed")
# Out:
# Hello World!
# Welcome to Python
# Microsoft AI Nirman Program
# ...
# Samarth
# 22
# Artificial Intelligence
# ...
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# ...
# 20
# 88.5
# Samarth
# True
# ...
# Enter  your name:samarth
# Hello samarth
# ...
# Enter your age:55
# Your age is 55
# ...
# Addition is: 30
# Substraction is: -10
# Multiplication is: 200
# Division is: 0.5
# Modulos is 10
# False
# True
# False
# True
# True
# False
# ...
# You are Eligible to Vote
# You are Eligible to Vote
# Grade B
# Entery Allowed

# %%
# Practice Questions

#1.Write ab program for tak studnt info from user and then print this info clean format.
name = input("Enter your Full Name:")
age = int(input("Enter your Age:"))
course = input("Enter your Course Name:")
college = input("Enter your College Name(Short Form):")
print("="*30)
print("Name:",name)
print("Age:",age)
print("College",college)
print("Course:",course)
print("="*30)
# Out:
# Enter your Full Name:Samarth Kokate
# Enter your Age:55
# Enter your Course Name:Data Science
# Enter your College Name(Short Form):SCET NGP
# ...
# Name: Samarth Kokate
# Age: 55
# College SCET NGP
# Course: Data Science
# ...

# %%
# 2.Write a program for Simple Calculator
num1 = int(input("Enter First Number:"))
num2 = int(input("Enter Second Number:"))
print("1:Addition\n2:Substraction\n3:Multiplication\n4:Division")
choice = int(input("Enter Your Choice:"))
if choice == 1:
  print("Addition is",num1+num2)
elif choice == 2:
  print("Substraction is",num1-num2)
elif choice == 3:
  print("Multiplication is",num1*num2)
elif choice == 4:
  print("Division is",num1/num2)
else:
  print("Invalid Choice")
# Out:
# Enter First Number:45
# Enter Second Number:12
# 1:Addition
# 2:Substraction
# 3:Multiplication
# 4:Division
# Enter Your Choice:1
# Addition is 57

# %%
# 3.Write program for simple average mark and persentage calculator
print("Enter Marks out of 1004")
sub1 = int(input("Enter First Subject Marks:"))
sub2 = int(input("Enter Second Subject Marks:"))
sub3 = int(input("Enter Third Subject Marks:"))
sub4 = int(input("Enter Fourth Subject Marks:"))
sub5 = int(input("Enter Fifth Subject Marks:"))
sub6 = int(input("Enter Sixth Subject Marks:"))
average_marks = (sub1+sub2+sub3+sub4+sub5+sub6)/6
percentage = (average_marks/100)*100
print("Average Marks is:",average_marks)
print("Percentage is",percentage)
# Out:
# Enter Marks out of 100
# Enter First Subject Marks:55
# Enter Second Subject Marks:56
# Enter Third Subject Marks:89
# Enter Fourth Subject Marks:5
# Enter Fifth Subject Marks:56
# Enter Sixth Subject Marks:56
# Average Marks is: 52.833333333333336
# Percentage is 52.83333333333333

# %%
# 4. write a program for temprature conersion (C to F)
cel = float(input("Enter Temperature in Celcius:"))
far = (cel*9/5)+32
print("Conversion of C to F is:",far)
# Out:
# Enter Temperature in Celcius:40
# Conversion of C to F is: 104.0

# %%
# 5. write  program for imple interst calclator

principle_amount = float(input("Enter Principle Amount:"))
rate = float(input("Enter Rate"))
time = float(input("Enter time in number of Months(Number Only):"))
simple_interest = (principle_amount*rate*time)/100
print("Your Simple interest is:",simple_interest)
# Out:
# Enter Principle Amount:100
# Enter Rate3
# Enter time in number of Months(Number Only):7
# Your Simple interest is: 21.0
